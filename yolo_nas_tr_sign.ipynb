# %%
import torch
import torchvision.models as models

# %%
# %pwd
# Out:
# 'C:\\Users\\ashwi\\workspace'

# %%
pwd
# Out:
# 'C:\\Users\\ashwi\\workspace'

# %%
import os
from random import choice
import shutil

# %%
#arrays to store file names
imgs =[]
xmls =[]

#setup dir names
trainPath = 'E:/FINAL PROJECT/important/dataset/images/train'
valPath = 'E:/FINAL PROJECT/important/dataset/images/val'
crsPath = 'E:/FINAL PROJECT/important/dataset/data' #dir where images and annotations stored

#setup ratio (val ratio = rest of the files in origin dir after splitting into train and test)
train_ratio = 0.8
val_ratio = 0.2


#total count of imgs
totalImgCount = len(os.listdir(crsPath))/2

#soring files to corresponding arrays
for (dirname, dirs, files) in os.walk(crsPath):
    for filename in files:
        if filename.endswith('.txt'):
            xmls.append(filename)
        else:
            imgs.append(filename)


#counting range for cycles
countForTrain = int(len(imgs)*train_ratio)
countForVal = int(len(imgs)*val_ratio)
print("training images are : ",countForTrain)
print("Validation images are : ",countForVal)
# Out:
# training images are :  592
# Validation images are :  148

# %%
# !pip install super-gradients
# Out:
# ...
#   Using cached super_gradients-3.1.2-py3-none-any.whl (983 kB)
# ...
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# ...
#   Using cached coverage-5.3.1-cp39-cp39-win_amd64.whl (212 kB)
# ...
#   Using cached torchvision-0.15.2-cp39-cp39-win_amd64.whl (1.2 MB)
# ...
#   Using cached Sphinx-4.0.3-py3-none-any.whl (2.9 MB)
# ...
#   Using cached sphinx_rtd_theme-1.2.2-py2.py3-none-any.whl (2.8 MB)
# ...
#   Using cached torchmetrics-0.8.0-py3-none-any.whl (408 kB)
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# ...
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# ...
#   Using cached onnxruntime-1.13.1-cp39-cp39-win_amd64.whl (5.9 MB)
# ...
#   Using cached onnx-1.13.0-cp39-cp39-win_amd64.whl (12.2 MB)
# ...
#   Using cached pip_tools-6.14.0-py3-none-any.whl (55 kB)
# ...
#   Using cached pyparsing-2.4.5-py2.py3-none-any.whl (67 kB)
# ...
#   Using cached einops-0.3.2-py3-none-any.whl (25 kB)
# ...
#   Using cached pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies: started
# ...

# %%
from super_gradients.training import Trainer

# %%
# !python --version
# Out:
# Python 3.9.12

# %%
import torch
torch.__version__
# Out:
# '2.0.1+cpu'

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 import torch
# ----> 2 torch.cuda.get_device_name(0)
#
# File ~\anaconda3\envs\tfenv\lib\site-packages\torch\cuda\__init__.py:365, in get_device_name(device)
#     353 def get_device_name(device: Optional[_device_t] = None) -> str:
#     354     r"""Gets the name of a device.
#     355
#     356     Args:
#    (...)
#     363         str: the name of the device
#     364     """
# --> 365     return get_device_properties(device).name
#
# File ~\anaconda3\envs\tfenv\lib\site-packages\torch\cuda\__init__.py:395, in get_device_properties(device)
#     385 def get_device_properties(device: _device_t) -> _CudaDeviceProperties:
#     386     r"""Gets the properties of a device.
#     387
#     388     Args:
#    (...)
#     393         _CudaDeviceProperties: the properties of the device
#     394     """
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.13
# anaconda-client               1.9.0
# anaconda-navigator            2.4.0
# anaconda-project              0.10.2
# antlr4-python3-runtime        4.9.3
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.12.1
# ...

# %%
dataset_params = {
    'data_dir':'/content/gdrive/My Drive/yolo_nas/dataset/images/val/data',
    'train_images_dir': '/content/gdrive/My Drive/yolo_nas/dataset/images/train',
    'train_labels_dir':'/content/gdrive/My Drive/yolo_nas/dataset/labels/train',
    'val_images_dir':'/content/gdrive/My Drive/yolo_nas/dataset/images/val',
    'val_labels_dir':'/content/gdrive/My Drive/yolo_nas/dataset/labels/val',
    'classes': ["prohibitory", "danger","mandatory","other"]
                            }

# %%
from super_gradients.training import models
model = models.get('yolo_nas_l', 
                   num_classes=len(dataset_params['classes']), 
                   pretrained_weights="coco"
                   )
# Out:
# Downloading: "https://sghub.deci.ai/models/yolo_nas_l_coco.pth" to C:\Users\ashwi/.cache\torch\hub\checkpoints\yolo_nas_l_coco.pth
# 100.0%

# %%
best_model = models.get('yolo_nas_l',
                        num_classes=len(dataset_params['classes']),
                        checkpoint_path="D:/PROJECTS/checkpoints/my_first_yolonas_run/ckpt_best.pth")
                        #checkpoint_path="checkpoints/my_first_yolonas_run/average_model.pth")

# %%
Trainer.test(model=best_model,
            test_loader=test_data,
            test_metrics_list=DetectionMetrics_050(score_thres=0.1, 
                                                   top_k_predictions=300, 
                                                   num_cls=len(dataset_params['classes']), 
                                                   normalize_targets=True, 
                                                   post_prediction_callback=PPYoloEPostPredictionCallback(score_threshold=0.01, 
                                                                                                          nms_top_k=1000, 
                                                                                                          max_predictions=300,                                                                              
                                                                                                          nms_threshold=0.7)
                                                  ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 Trainer.test(model=best_model,
# ----> 2             test_loader=test_data,
#       3             test_metrics_list=DetectionMetrics_050(score_thres=0.1,
#       4                                                    top_k_predictions=300,
#       5                                                    num_cls=len(dataset_params['classes']),
#       6                                                    normalize_targets=True,
#       7                                                    post_prediction_callback=PPYoloEPostPredictionCallback(score_threshold=0.01,
#       8                                                                                                           nms_top_k=1000,
# ...

# %%
test_image = "D:/PROJECTS/dataset-ywth/dataset/images/val/00011.jpg
best_model.predict(test_image).show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 2
#       1 test_image = "D:/PROJECTS/dataset-ywth/dataset/images/val/00011.jpg"
# ----> 2 best_model.predict(test_image).show()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\super_gradients\training\models\detection_models\customizable_detector.py:177, in CustomizableDetector.predict(self, images, iou, conf, fuse_model)
#     168 """Predict an image or a list of images.
#     169
#     170 :param images:  Images to predict.
#    (...)
#     174 :param fuse_model: If True, create a copy of the model, and fuse some of its layers to increase performance. This increases memory usage.
#     175 """
#     176 pipeline = self._get_pipeline(iou=iou, conf=conf, fuse_model=fuse_model)
# --> 177 return pipeline(images)
#
# ...
